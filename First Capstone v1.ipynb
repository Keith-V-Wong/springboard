# %%
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
import numpy as np

# %%
df = pd.read_csv('/home/keith/Springboard/LoanStats3d.csv', low_memory = False, skiprows = [0,2])

# %%
df.shape
# Out:
# (421096, 111)

# %%
df.dtypes
# Out:
# id                                 object
# member_id                         float64
# loan_amnt                         float64
# funded_amnt                       float64
# funded_amnt_inv                   float64
# term                               object
# int_rate                           object
# installment                       float64
# grade                              object
# sub_grade                          object
# emp_title                          object
# emp_length                         object
# home_ownership                     object
# annual_inc                        float64
# verification_status                object
# issue_d                            object
# loan_status                        object
# pymnt_plan                         object
# url                               float64
# desc                               object
# purpose                            object
# title                              object
# ...

# %%
df.head(10)
# Out:
#     id  member_id  loan_amnt  funded_amnt  funded_amnt_inv        term  \
# 0  NaN        NaN    15000.0      15000.0          15000.0   36 months
# 1  NaN        NaN     8000.0       8000.0           8000.0   36 months
# 2  NaN        NaN    15000.0      15000.0          15000.0   36 months
# 3  NaN        NaN    25000.0      25000.0          25000.0   60 months
# 4  NaN        NaN    12000.0      12000.0          12000.0   36 months
# 5  NaN        NaN     5000.0       5000.0           5000.0   36 months
# 6  NaN        NaN    18500.0      18500.0          18500.0   60 months
# 7  NaN        NaN    15000.0      15000.0          15000.0   60 months
# 8  NaN        NaN    17925.0      17925.0          17925.0   60 months
# 9  NaN        NaN    10000.0      10000.0          10000.0   36 months
#
#   int_rate  installment grade sub_grade            ...              \
# 0    8.49%       473.45     B        B1            ...
# 1   10.78%       261.08     B        B4            ...
# ...

# %%
df.tail(10)
# Out:
#                                                       id  member_id  \
# 421086                                               NaN        NaN
# 421087                                               NaN        NaN
# 421088                                               NaN        NaN
# 421089                                               NaN        NaN
# 421090                                               NaN        NaN
# 421091                                               NaN        NaN
# 421092                                               NaN        NaN
# 421093                                               NaN        NaN
# 421094  Total amount funded in policy code 1: 6417608175        NaN
# 421095  Total amount funded in policy code 2: 1944088810        NaN
#
#         loan_amnt  funded_amnt  funded_amnt_inv        term int_rate  \
# 421086     7500.0       7500.0           7500.0   36 months    9.49%
# 421087    11575.0      11575.0          11575.0   36 months   15.59%
# ...

# %%
df1 = df.drop([421094, 421095])
df1
# Out:
#          id  member_id  loan_amnt  funded_amnt  funded_amnt_inv        term  \
# 0       NaN        NaN    15000.0      15000.0          15000.0   36 months
# 1       NaN        NaN     8000.0       8000.0           8000.0   36 months
# 2       NaN        NaN    15000.0      15000.0          15000.0   36 months
# 3       NaN        NaN    25000.0      25000.0          25000.0   60 months
# 4       NaN        NaN    12000.0      12000.0          12000.0   36 months
# 5       NaN        NaN     5000.0       5000.0           5000.0   36 months
# 6       NaN        NaN    18500.0      18500.0          18500.0   60 months
# 7       NaN        NaN    15000.0      15000.0          15000.0   60 months
# 8       NaN        NaN    17925.0      17925.0          17925.0   60 months
# 9       NaN        NaN    10000.0      10000.0          10000.0   36 months
# 10      NaN        NaN    14000.0      14000.0          14000.0   36 months
# ...

# %%
df1['loan_amnt'].unique()
# Out:
# array([ 15000.,   8000.,  25000., ...,  34525.,   1625.,  30275.])

# %%
df1['term'].unique()
# Out:
# array([' 36 months', ' 60 months'], dtype=object)

# %%
df1['loan_status'].unique()
# Out:
# array(['Fully Paid', 'Current', 'Late (31-120 days)', 'Charged Off',
#        'Late (16-30 days)', 'In Grace Period', 'Default'], dtype=object)

# %%
df1['emp_length'].unique()
# Out:
# array(['6 years', '< 1 year', '1 year', '10+ years', '4 years', '2 years',
#        '3 years', '9 years', '5 years', 'n/a', '7 years', '8 years'], dtype=object)

# %%
# Out:
# id                                 object
# member_id                         float64
# loan_amnt                         float64
# funded_amnt                       float64
# funded_amnt_inv                   float64
# term                               object
# int_rate                           object
# installment                       float64
# grade                              object
# sub_grade                          object
# emp_title                          object
# emp_length                         object
# home_ownership                     object
# annual_inc                        float64
# verification_status                object
# issue_d                            object
# loan_status                        object
# pymnt_plan                         object
# url                               float64
# desc                               object
# purpose                            object
# title                              object
# ...
